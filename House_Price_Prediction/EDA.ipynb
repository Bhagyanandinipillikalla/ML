# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df=df.drop(columns=['area_type','availability','society','balcony'])

# %%
df
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
df['location'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316               Richards Town
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13320, dtype: object>

# %%
df['location'].isna().sum()
# Out:
# 1

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: count, Length: 1305, dtype: int64

# %%
df['location']=df['location'].fillna('Sarjapur Road')

# %%
df['location']=df['location'].apply(lambda x:x.strip())

# %%
df['size'].isnull().sum()
# Out:
# 16

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
df['size']=df['size'].fillna('2 BHK')

# %%
df['bath'].isna().sum()
# Out:
# 73

# %%
df['bath'].value_counts()
# Out:
# bath
# 2.0     6908
# 3.0     3286
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 13.0       3
# 11.0       3
# 16.0       2
# 27.0       1
# 40.0       1
# 15.0       1
# 14.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
df['bath']=df['bath'].fillna(2)

# %%
df['bath']=df['bath'].astype(int)

# %%
loc=df['location'].value_counts()
loc_less_than_10=loc[loc<=10]
df['location']=df['location'].apply(lambda x:"others" if x in loc_less_than_10 else x)

# %%
out=[int(i.split()[0]) for i in df['size']]
df['bhk']=out
df
# Out:
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600     5  120.00    4
# 2                   Uttarahalli      3 BHK       1440     2   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521     3   95.00    3
# 4                      Kothanur      2 BHK       1200     2   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453     4  231.00    5
# 13316                    others      4 BHK       3600     5  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141     2   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689     4  488.00    4
# 13319              Doddathoguru      1 BHK        550     1   17.00    1
#
# [13320 rows x 6 columns]

# %%
df['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200    843
# 1100    221
# 1500    205
# 2400    196
# 600     180
#        ...
# 3580      1
# 2461      1
# 1437      1
# 2155      1
# 4689      1
# Name: count, Length: 2117, dtype: int64

# %%
def clean_sqft(sqft):
    l=sqft.split("-")
    if len(l)==2:
        return float(l[0])+float(l[1])/2
    try:
        return float(l[0])
    except: 
        return None
df['total_sqft']=df['total_sqft'].apply(clean_sqft)

# %%
df['total_sqft'].value_counts()
# Out:
# total_sqft
# 1200.0    843
# 1100.0    221
# 1500.0    205
# 2400.0    199
# 600.0     180
#          ...
# 555.0       1
# 4830.0      1
# 2383.0      1
# 3080.0      1
# 4689.0      1
# Name: count, Length: 1999, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1052

# %%
df.drop_duplicates(inplace=True)

# %%
df['total_sqft'].isna().sum()
# Out:
# 44

# %%
df['total_sqft']=df['total_sqft'].fillna(round(df['total_sqft'].mean()))

# %%
df['total_sqft'].describe()
# Out:
# count    12268.000000
# mean      1593.074365
# std       1292.728327
# min          1.000000
# 25%       1100.000000
# 50%       1300.000000
# 75%       1704.250000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %%
df['price_per_sqft']=df['price']*100000/df['total_sqft']
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13314         Green Glen Layout      3 BHK      1715.0     3  112.00    3
# 13315                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13316                    others      4 BHK      3600.0     5  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13314     6530.612245
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
#
# [12268 rows x 7 columns]

# %%
df=df[df['total_sqft']/df['bhk']>=300]
df['total_sqft'].describe()
# Out:
# count    11540.000000
# mean      1632.012158
# std       1318.295051
# min        300.000000
# 25%       1125.000000
# 50%       1322.000000
# 75%       1740.000000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %%
sns.boxplot(x='price_per_sqft',data=df)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
q1=df['price_per_sqft'].quantile(0.25)
q3=df['price_per_sqft'].quantile(0.75)

IQR=q3-q1

lower=q1-0.5*IQR
upper=q3+0.5*IQR

# %%
df=df[(df['price_per_sqft']>=lower) & (df['price_per_sqft']<=upper)]

# %%
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13310              Rachenahalli      2 BHK      1050.0     2   52.71    2
# 13312                 Bellandur      2 BHK      1262.0     2   47.00    2
# 13314         Green Glen Layout      3 BHK      1715.0     3  112.00    3
# 13315                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13310     5020.000000
# 13312     3724.247227
# 13314     6530.612245
# 13315     6689.834926
# 13317     5258.545136
#
# [9492 rows x 7 columns]

# %%
sns.boxplot(x='price_per_sqft',data=df)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df.reset_index(inplace=True)

# %%
df=df.drop(['index','price_per_sqft','size'],axis=1)
df
# Out:
#                       location  total_sqft  bath   price  bhk
# 0     Electronic City Phase II      1056.0     2   39.07    2
# 1             Chikka Tirupathi      2600.0     5  120.00    4
# 2                  Uttarahalli      1440.0     2   62.00    3
# 3           Lingadheeranahalli      1521.0     3   95.00    3
# 4                     Kothanur      1200.0     2   51.00    2
# ...                        ...         ...   ...     ...  ...
# 9487              Rachenahalli      1050.0     2   52.71    2
# 9488                 Bellandur      1262.0     2   47.00    2
# 9489         Green Glen Layout      1715.0     3  112.00    3
# 9490                Whitefield      3453.0     4  231.00    5
# 9491     Raja Rajeshwari Nagar      1141.0     2   60.00    2
#
# [9492 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import r2_score

# %%
encoder=LabelEncoder()
df['encoded_loc']=encoder.fit_transform(df['location'])
df
# Out:
#                       location  total_sqft  bath   price  bhk  encoded_loc
# 0     Electronic City Phase II      1056.0     2   39.07    2           78
# 1             Chikka Tirupathi      2600.0     5  120.00    4           60
# 2                  Uttarahalli      1440.0     2   62.00    3          225
# 3           Lingadheeranahalli      1521.0     3   95.00    3          158
# 4                     Kothanur      1200.0     2   51.00    2          150
# ...                        ...         ...   ...     ...  ...          ...
# 9487              Rachenahalli      1050.0     2   52.71    2          192
# 9488                 Bellandur      1262.0     2   47.00    2           43
# 9489         Green Glen Layout      1715.0     3  112.00    3           86
# 9490                Whitefield      3453.0     4  231.00    5          234
# 9491     Raja Rajeshwari Nagar      1141.0     2   60.00    2          193
#
# [9492 rows x 6 columns]

# %%
x=df.drop(['location','price'],axis=1)
y=df.price
x
# Out:
#       total_sqft  bath  bhk  encoded_loc
# 0         1056.0     2    2           78
# 1         2600.0     5    4           60
# 2         1440.0     2    3          225
# 3         1521.0     3    3          158
# 4         1200.0     2    2          150
# ...          ...   ...  ...          ...
# 9487      1050.0     2    2          192
# 9488      1262.0     2    2           43
# 9489      1715.0     3    3           86
# 9490      3453.0     4    5          234
# 9491      1141.0     2    2          193
#
# [9492 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=RandomForestRegressor(random_state=42)

# %%
params={
    "n_estimators":[100,150,200,250,300],
    "max_depth":[3,4,5,6,7]
}

# %%
grid=GridSearchCV(estimator=model,param_grid=params,cv=5)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [3, 4, 5, 6, 7],
#                          'n_estimators': [100, 150, 200, 250, 300]})

# %%
grid.score(x_train,y_train)
# Out:
# 0.8676380852757799

# %%
grid.score(x_test,y_test)
# Out:
# 0.85349996470154

# %%
from sklearn.linear_model import  LinearRegression

# %%
L_model=LinearRegression()
L_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
L_model.score(x_train,y_train)
# Out:
# 0.8203885764233041

# %%
L_model.score(x_test,y_test)
# Out:
# 0.8777050339574984

# %%
df.to_csv("Cleaned_df.csv")

# %%
import joblib
with open("RF_model.joblib","wb")as file:
    joblib.dump(grid,file)
